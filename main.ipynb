# %% [markdown]
# # About Dataset
# ## Uber and Ola Play Store Reviews Dataset
# ### Description:
# This dataset contains Play Store reviews for two prominent car services, Uber 🚗 and Ola 🚕. It provides valuable insights into user experiences, feedback, and sentiments towards these ride-sharing apps. The dataset includes various attributes such as review ID, user name, review title, review description, rating, thumbs up count, review date, developer response, developer response date, app version, language code, and country code. The dataset is a valuable resource for analyzing user sentiments, trends, and contributing factors that impact user satisfaction.
#
#
#
# ### Potential Use Cases:
#
# - Sentiment Analysis: Understand user sentiment towards Uber and Ola through sentiment analysis of reviews.
# - Rating Analysis: Analyze the distribution of ratings and trends in user satisfaction.
# - Top Contributors: Identify influential users based on review count and thumbs up count.
# - Developer Response Impact: Investigate whether developer responses influence user satisfaction.
# - Feature Request Analysis: Analyze recurring keywords to identify common feature requests.
# - Geographical Insights: Explore user sentiments and ratings across different countries.
# - App Version Analysis: Study user sentiments based on different app versions.
# - User Experience Trends: Extract insights from recurring keywords in review titles and descriptions.

# %% [markdown]
# # Business Intelligence II – Report / Term paper
# + __Introduction__ :
# Briefly state your motivation for the analysis.
# + __Dataset Description__ :
# Provide comprehensive details about the dataset to establish context.
# + __Data Preprocessing__ :
# Discuss the steps involved in data preprocessing, including data cleansing and transformations.
# + __Exploratory Data Analysis (EDA)__ :
# Explain the EDA process, highlighting the creation and analysis of hypotheses.
# Share interesting insights and findings from the dataset.
# + __Outlier Identification (if applicable)__ :
# If applicable, describe how outliers were identified and their impact on the analysis.
# + __Data Visualization__ :
# Present meaningful plots and images, such as scatter plots, to visually represent the data.
# + __External Data Integration (if applicable)__ :
# If applicable, integrated and explain how additional external data sources were used into the analysis
# + __Machine Learning Model__ :
# Detail the process of training and testing at least one machine learning model using the dataset.
# + __Machine Learning Model Output and Added Value__ :
# Describe the output of your machine learning model and its contribution / added value to the analysis.
# + __Outlook__ :
# Discuss future steps and considerations, such as deployment strategies and addressing missing data.

# %% [markdown]
# # 1-Busnies Understanding
# Our project is about tow famous ride-hailing companies Ola and Uber, Ola is India’s largest mobility platform and one of the world’s largest ride-hailing companies, serving 250+ cities across India, Australia, New Zealand, and the UK. The Ola app offers mobility solutions by connecting customers to drivers and a wide range of vehicles across bikes, auto-rickshaws, metered taxis, and cabs.
# Uber is a ride-hailing services, food delivery, and freight transport ,Uber operate in approximately 70 countries and 10,500 cities worldwide, its one of the largest with 131 million monthly active user.
# And those tow ride-hailing giant companies most of the Business depends on there Apps the Ola app and Uber app that  mean by the app they interact with their Customers and in every Business Customer Satisfaction is key roll to any company success , that’s why we have decided to investigate the Ola Vs Uber Reviews Data Sets and check the customer feedback for both of the companies and check how the companies doing with their customer satisfaction

# %% [markdown]
# # 2-Data Understanding
# That set of data includes Play Store reviews for two well-known car services, Uber and Ola. It provides valuable insights into user experiences, feedback and sentiments towards these ride-sharing apps. The dataset includes various attributes such as review ID, username, review title, review description, rating, number of thumbs up, review date, developer response, developer response date, app version, language code and country code.
#
# ### Columns:
#
# - review_id: A unique identifier for each review.
# - user_name: The username associated with the review.
# - review_title: The title of the review.
# - review_description: The main content of the review provided by the user.
# - rating: The user's rating for the app (e.g., on a scale of 1 to 5) where 1 is very bad and 5 is very good .
# - thumbs_up: The count of thumbs up given by other users for this review.
# - review_date: The date when the review was posted.
# - developer_response: Any response provided by the app developer to the review.
# - developer_response_date: The date of the developer's response.
# - appVersion: The version of the app when the review was submitted.
# - language_code: The code representing the language of the review.
# - country_code: The code representing the country of the user.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
ola_df=pd.read_csv("Ola Customer Reviews.csv", sep=",")
uber_df=pd.read_csv("Uber Customer Reviews.csv",sep=",")
# Out:
# C:\Users\AliMa\AppData\Local\Temp\ipykernel_29944\4071479778.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   ola_df=pd.read_csv("Ola Customer Reviews.csv", sep=",")
# C:\Users\AliMa\AppData\Local\Temp\ipykernel_29944\4071479778.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   uber_df=pd.read_csv("Uber Customer Reviews.csv",sep=",")

# %%
ola_df.head(2)
# Out:
#         source                             review_id      user_name  \
# 0  Google Play  fbc7ffc9-5a89-446e-87fd-d69bf4a7f984  Puipuii Ralte
# 1  Google Play  5a0051fb-220a-45b2-ba94-a15a2949218f   Deepak Kumar
#
#   review_title                                 review_description  rating  \
# 0          NaN  The map in Ola is so messed up, i have to pay ...       1
# 1          NaN                            Deepak Kumar.... 🙏🙏🙏🙏🙏]       5
#
#    thumbs_up          review_date developer_response developer_response_date  \
# 0        0.0  2023-08-10 16:40:50                NaN                     NaN
# 1        0.0  2023-08-10 16:36:14                NaN                     NaN
#
#   appVersion laguage_code country_code
# 0      6.3.2           en           in
# 1        NaN           en           in

# %%
ola_df.shape
# Out:
# (357698, 13)

# %%
uber_df.head(2)
# Out:
#         source                             review_id       user_name  \
# 0  Google Play  18d6584c-d0e9-4833-a744-f607058aee97       Milky Way
# 1  Google Play  50a08f18-cece-4ddf-b617-028844c8aa28  Bradlee Severa
#
#   review_title                                 review_description  rating  \
# 0          NaN  Suddenly, the driver can't have my location an...       1
# 1          NaN  Very cordial.. And helped with a quick turnaro...       5
#
#    thumbs_up          review_date developer_response developer_response_date  \
# 0        0.0  2023-08-10 17:48:51                NaN                     NaN
# 1        0.0  2023-08-10 17:38:35                NaN                     NaN
#
#     appVersion laguage_code country_code
# 0          NaN           en           in
# 1  4.485.10000           en           in

# %%
uber_df.shape
# Out:
# (1069616, 13)

# %%
ola_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357698 entries, 0 to 357697
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   source                   357698 non-null  object
#  1   review_id                357698 non-null  object
#  2   user_name                357698 non-null  object
#  3   review_title             891 non-null     object
#  4   review_description       357682 non-null  object
#  5   rating                   357698 non-null  int64
#  6   thumbs_up                356807 non-null  float64
#  7   review_date              357698 non-null  object
#  8   developer_response       124769 non-null  object
#  9   developer_response_date  124590 non-null  object
#  10  appVersion               275326 non-null  object
#  11  laguage_code             357698 non-null  object
#  12  country_code             357698 non-null  object
# dtypes: float64(1), int64(1), object(11)
# ...

# %%
uber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069616 entries, 0 to 1069615
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   source                   1069616 non-null  object
#  1   review_id                1069616 non-null  object
#  2   user_name                1069615 non-null  object
#  3   review_title             2180 non-null     object
#  4   review_description       1069501 non-null  object
#  5   rating                   1069616 non-null  int64
#  6   thumbs_up                1067436 non-null  float64
#  7   review_date              1069616 non-null  object
#  8   developer_response       198264 non-null   object
#  9   developer_response_date  197278 non-null   object
#  10  appVersion               828068 non-null   object
#  11  laguage_code             1069616 non-null  object
#  12  country_code             1069616 non-null  object
# ...

# %% [markdown]
# # 3-Data Prepartion

# %% [markdown]
# #### converting the column review Date to date and time and exporting year month and day

# %%
#converting the date column from object to datetime 
ola_df['review_date'] = pd.to_datetime(ola_df['review_date'])
uber_df['review_date'] = pd.to_datetime(uber_df['review_date'])

# Extract day, month, and year into separate columns
ola_df['Day'] = ola_df['review_date'].dt.day
ola_df['Month'] = ola_df['review_date'].dt.month
ola_df['Year'] = ola_df['review_date'].dt.year

# Extract day, month, and year into separate columns
uber_df['Day'] = uber_df['review_date'].dt.day
uber_df['Month'] = uber_df['review_date'].dt.month
uber_df['Year'] = uber_df['review_date'].dt.year

# %%
ola_df.head(3)
# Out:
#         source                             review_id         user_name  \
# 0  Google Play  fbc7ffc9-5a89-446e-87fd-d69bf4a7f984     Puipuii Ralte
# 1  Google Play  5a0051fb-220a-45b2-ba94-a15a2949218f      Deepak Kumar
# 2  Google Play  71ebf933-b734-474d-bb65-a18c90906ed2  Ahamed Azarudeen
#
#   review_title                                 review_description  rating  \
# 0          NaN  The map in Ola is so messed up, i have to pay ...       1
# 1          NaN                            Deepak Kumar.... 🙏🙏🙏🙏🙏]       5
# 2          NaN  Such aa irresponsible app more then I waiting ...       1
#
#    thumbs_up         review_date developer_response developer_response_date  \
# 0        0.0 2023-08-10 16:40:50                NaN                     NaN
# 1        0.0 2023-08-10 16:36:14                NaN                     NaN
# 2        0.0 2023-08-10 16:29:31                NaN                     NaN
#
#   appVersion laguage_code country_code  Day  Month  Year
# ...

# %%
uber_df.head(3)
# Out:
#         source                             review_id       user_name  \
# 0  Google Play  18d6584c-d0e9-4833-a744-f607058aee97       Milky Way
# 1  Google Play  50a08f18-cece-4ddf-b617-028844c8aa28  Bradlee Severa
# 2  Google Play  b0d8e75a-80a7-4dcd-abaf-72b046dbeeb7   Amit Aggarwal
#
#   review_title                                 review_description  rating  \
# 0          NaN  Suddenly, the driver can't have my location an...       1
# 1          NaN  Very cordial.. And helped with a quick turnaro...       5
# 2          NaN                               Very good experience       5
#
#    thumbs_up         review_date developer_response developer_response_date  \
# 0        0.0 2023-08-10 17:48:51                NaN                     NaN
# 1        0.0 2023-08-10 17:38:35                NaN                     NaN
# 2        0.0 2023-08-10 17:38:17                NaN                     NaN
#
#     appVersion laguage_code country_code  Day  Month  Year
# ...

# %% [markdown]
# #### Catogrizing the Reviews

# %%
# Define a function to catgorize the rating 
def categorize_rating(rating):
    if rating >= 4.0:
        return 'Positive'
    elif rating >= 3.0:
        return 'Neutral'
    else:
        return 'Negative'

# applying function to create a new 'Category' column
ola_df['rating_type'] = ola_df['rating'].apply(categorize_rating)
uber_df['rating_type'] = uber_df['rating'].apply(categorize_rating)

# %% [markdown]
# #### Normlizing the text

# %%
# Convert the review_description to a string
ola_df['review_description'] = ola_df['review_description'].astype(str)
uber_df['review_description'] = uber_df['review_description'].astype(str)

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Function to preprocess a text string
def preprocess_text(text):
    # Convert to lowercase
    lower_string = text.lower()

    # Remove numbers
    no_number_string = re.sub(r'\d+', '', lower_string)

    # Remove all punctuation except words and space
    no_punc_string = re.sub(r'[^\w\s]', '', no_number_string)

    # Remove white spaces
    no_wspace_string = no_punc_string.strip()

    # Convert string to list of words
    lst_string = [no_wspace_string][0].split()

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    no_stpwords_string = " ".join(word for word in lst_string if word not in stop_words)

    return no_stpwords_string
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AliMa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Apply the preprocessing function to the 'review_description' column
ola_df['normalized_review_description'] = ola_df['review_description'].apply(preprocess_text)
uber_df['normalized_review_description'] = uber_df['review_description'].apply(preprocess_text)
# Display the DataFrame with the normalized review descriptions
ola_df[['review_description', 'normalized_review_description']].head(2)
# Out:
#                                   review_description  \
# 0  The map in Ola is so messed up, i have to pay ...
# 1                            Deepak Kumar.... 🙏🙏🙏🙏🙏]
#
#                        normalized_review_description
# 0  map ola messed pay rs extra map incorrect app ...
# 1                                       deepak kumar

# %%
uber_df[['review_description', 'normalized_review_description']].head(2)
# Out:
#                                   review_description  \
# 0  Suddenly, the driver can't have my location an...
# 1  Very cordial.. And helped with a quick turnaro...
#
#                        normalized_review_description
# 0  suddenly driver cant location calling ask goin...
# 1     cordial helped quick turnaround ride well done

# %%
uber_df[['review_description', 'normalized_review_description']].drop_duplicates()
# Out:
#                                         review_description  \
# 0        Suddenly, the driver can't have my location an...
# 1        Very cordial.. And helped with a quick turnaro...
# 2                                     Very good experience
# 3                                                All I use
# 4        I have enjoyed traveling by Uber my drivers ha...
# ...                                                    ...
# 1069611  I tried to find away to report problems direct...
# 1069612  I used to love Uber, specially the Uber pool s...
# 1069613  If I wanted to take a bus to be dropped off on...
# 1069614  Hello\n\nSTORY TIME\n\nI wanted to delete JUST...
# 1069615  The past couple times I’ve ridden with Uber, I...
#
#                              normalized_review_description
# 0        suddenly driver cant location calling ask goin...
# 1           cordial helped quick turnaround ride well done
# 2                                          good experience
# ...

# %%
ola_df[['review_description', 'normalized_review_description']].drop_duplicates()
# Out:
#                                        review_description  \
# 0       The map in Ola is so messed up, i have to pay ...
# 1                                 Deepak Kumar.... 🙏🙏🙏🙏🙏]
# 2       Such aa irresponsible app more then I waiting ...
# 3                                                   Worst
# 4       Too much expensive .. try UBer... They are pro...
# ...                                                   ...
# 357693  The app is useless for new users since you can...
# 357694  Do not recharge money with ola money.. I have ...
# 357695  The app hangs on signup. Later I get authentic...
# 357696  one of the worst app for iphone.i was tried mu...
# 357697  This company is hopeless. I waited on hold for...
#
#                             normalized_review_description
# 0       map ola messed pay rs extra map incorrect app ...
# 1                                            deepak kumar
# 2       aa irresponsible app waiting hour waste app pl...
# ...

# %% [markdown]
# #### outlier detection
# as we can see we dont have outliersin the rating column

# %%
ola_df.head(2)
# Out:
#         source                             review_id      user_name  \
# 0  Google Play  fbc7ffc9-5a89-446e-87fd-d69bf4a7f984  Puipuii Ralte
# 1  Google Play  5a0051fb-220a-45b2-ba94-a15a2949218f   Deepak Kumar
#
#   review_title                                 review_description  rating  \
# 0          NaN  The map in Ola is so messed up, i have to pay ...       1
# 1          NaN                            Deepak Kumar.... 🙏🙏🙏🙏🙏]       5
#
#    thumbs_up         review_date developer_response developer_response_date  \
# 0        0.0 2023-08-10 16:40:50                NaN                     NaN
# 1        0.0 2023-08-10 16:36:14                NaN                     NaN
#
#   appVersion laguage_code country_code  Day  Month  Year rating_type  \
# 0      6.3.2           en           in   10      8  2023    Negative
# 1        NaN           en           in   10      8  2023    Positive
#
#                        normalized_review_description
# ...

# %%
uber_df.head(2)
# Out:
#         source                             review_id       user_name  \
# 0  Google Play  18d6584c-d0e9-4833-a744-f607058aee97       Milky Way
# 1  Google Play  50a08f18-cece-4ddf-b617-028844c8aa28  Bradlee Severa
#
#   review_title                                 review_description  rating  \
# 0          NaN  Suddenly, the driver can't have my location an...       1
# 1          NaN  Very cordial.. And helped with a quick turnaro...       5
#
#    thumbs_up         review_date developer_response developer_response_date  \
# 0        0.0 2023-08-10 17:48:51                NaN                     NaN
# 1        0.0 2023-08-10 17:38:35                NaN                     NaN
#
#     appVersion laguage_code country_code  Day  Month  Year rating_type  \
# 0          NaN           en           in   10      8  2023    Negative
# 1  4.485.10000           en           in   10      8  2023    Positive
#
#                        normalized_review_description
# ...

# %%
# creating a boxplot to check for outliers in the rating columns for both of the datasets

fig, axes = plt.subplots(1, 2, figsize=(9, 5))  


sns.boxplot(data=ola_df["rating"], ax=axes[0])
axes[0].set_title(" Ola Rating ")


sns.boxplot(data=uber_df["rating"], ax=axes[1])
axes[1].set_title("Uber Rating")


plt.tight_layout()


plt.show()

# %% [markdown]
# # 4-EDA

# %% [markdown]
# ## A-Rating Analysis: Analyze the distribution of ratings and trends in user satisfaction.

# %%
ola_df["rating"].describe()
# Out:
# count    357698.00000
# mean          2.77325
# std           1.85194
# min           1.00000
# 25%           1.00000
# 50%           2.00000
# 75%           5.00000
# max           5.00000
# Name: rating, dtype: float64

# %%
uber_df["rating"].describe()
# Out:
# count    1.069616e+06
# mean     3.650441e+00
# std      1.743725e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      5.000000e+00
# 75%      5.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ola_df.head(2)
# Out:
#         source                             review_id      user_name  \
# 0  Google Play  fbc7ffc9-5a89-446e-87fd-d69bf4a7f984  Puipuii Ralte
# 1  Google Play  5a0051fb-220a-45b2-ba94-a15a2949218f   Deepak Kumar
#
#   review_title                                 review_description  rating  \
# 0          NaN  The map in Ola is so messed up, i have to pay ...       1
# 1          NaN                            Deepak Kumar.... 🙏🙏🙏🙏🙏]       5
#
#    thumbs_up         review_date developer_response developer_response_date  \
# 0        0.0 2023-08-10 16:40:50                NaN                     NaN
# 1        0.0 2023-08-10 16:36:14                NaN                     NaN
#
#   appVersion laguage_code country_code  Day  Month  Year rating_type  \
# 0      6.3.2           en           in   10      8  2023    Negative
# 1        NaN           en           in   10      8  2023    Positive
#
#                        normalized_review_description
# ...

# %%
ola_df["rating"].unique()
# Out:
# array([1, 5, 2, 3, 4], dtype=int64)

# %%
rating_count_ola=ola_df.groupby("rating")["review_id"].count().reset_index()
rating_count_ola
# Out:
#    rating  review_id
# 0       1     173200
# 1       2      15586
# 2       3      15991
# 3       4      24964
# 4       5     127957

# %%
rating_count_uber=uber_df.groupby("rating")["review_id"].count().reset_index()
rating_count_uber
# Out:
#    rating  review_id
# 0       1     283895
# 1       2      41707
# 2       3      49928
# 3       4      82953
# 4       5     611133

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))




axes[0].bar(rating_count_ola["rating"], rating_count_ola["review_id"],  label='Ola Dataset')
axes[0].set_title("Ola Ratings")
axes[0].set_xlabel('Ratings')
axes[0].set_ylabel('Values')
axes[0].legend()

axes[1].bar(rating_count_uber["rating"], rating_count_uber["review_id"], label='Uber Dataset')
axes[1].set_title('Uber Ratings')
axes[1].set_xlabel('Ratings')
axes[1].set_ylabel('Values')
axes[1].legend()


plt.tight_layout()


plt.show()

# %%
rating_type_count_ola=ola_df.groupby("rating_type")["review_id"].count().reset_index()
rating_type_count_ola
# Out:
#   rating_type  review_id
# 0    Negative     188786
# 1     Neutral      15991
# 2    Positive     152921

# %%
rating_type_count_uber=uber_df.groupby("rating_type")["review_id"].count().reset_index()
rating_type_count_uber
# Out:
#   rating_type  review_id
# 0    Negative     325602
# 1     Neutral      49928
# 2    Positive     694086

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].bar(rating_type_count_ola["rating_type"], rating_type_count_ola["review_id"],  label='Ola Dataset')
axes[0].set_title("Ola Ratings")
axes[0].set_xlabel('Ratings')
axes[0].set_ylabel('Values')
axes[0].legend()

axes[1].bar(rating_type_count_uber["rating_type"], rating_type_count_uber["review_id"], label='Uber Dataset')
axes[1].set_title('Uber Ratings')
axes[1].set_xlabel('Ratings')
axes[1].set_ylabel('Values')
axes[1].legend()


plt.tight_layout()


plt.show()

# %% [markdown]
# ##### Rating Avareges

# %%
# ola rating avarege
Avg_ola_rating=round(ola_df["rating"].mean(),2)
print(f"the Average of ola reviews is {Avg_ola_rating}")
# Out:
# the Average of ola reviews is 2.77

# %%
# uber rating avarege
Avg_uber_rating=round(uber_df["rating"].mean(),2)
print(f"the Average of uber reviews is {Avg_uber_rating}")
# Out:
# the Average of uber reviews is 3.65

# %% [markdown]
# ##### Rating Percentages

# %%
#percantge of good reviews by both companies 
#by ola
positive_reviwes_ola=ola_df[ola_df["rating_type"]=="Positive"]
positive_reviwes_ola["review_id"].count()
percentage_good_reviews_ola = (positive_reviwes_ola["review_id"].count() / ola_df["review_id"].count()) * 100
percentage_good_reviews_ola=round(percentage_good_reviews_ola)
print(f"the Positive Reviews are  {percentage_good_reviews_ola}% from all the reviews")
# Out:
# the Positive Reviews are  43% from all the reviews

# %%
#by Uber
positive_reviwes_uber=uber_df[uber_df["rating_type"]=="Positive"]
positive_reviwes_uber["review_id"].count()
percentage_good_reviews_uber = (positive_reviwes_uber["review_id"].count() / uber_df["review_id"].count()) * 100
percentage_good_reviews_uber=round(percentage_good_reviews_uber)
print(f"the Positive Reviews are  {percentage_good_reviews_uber}% from all the reviews")
# Out:
# the Positive Reviews are  65% from all the reviews

# %%
 #Create a pie chart
labels = ['Good Reviews', 'Negative Reviews']
sizes = [percentage_good_reviews_uber, 100 - percentage_good_reviews_uber]
colors = ['lightgreen', 'lightgray']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  

ax.set_title('Reviews Uber')

plt.show()

# %%
 
labels = ['Good Reviews', 'Negative Reviews']
sizes = [percentage_good_reviews_ola, 100 - percentage_good_reviews_ola]
colors = ['lightgreen', 'lightgray']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal') 

ax.set_title('Reviews Ola')


plt.show()

# %%
ola_df.head(2)
# Out:
#         source                             review_id      user_name  \
# 0  Google Play  fbc7ffc9-5a89-446e-87fd-d69bf4a7f984  Puipuii Ralte
# 1  Google Play  5a0051fb-220a-45b2-ba94-a15a2949218f   Deepak Kumar
#
#   review_title                                 review_description  rating  \
# 0          NaN  The map in Ola is so messed up, i have to pay ...       1
# 1          NaN                            Deepak Kumar.... 🙏🙏🙏🙏🙏]       5
#
#    thumbs_up         review_date developer_response developer_response_date  \
# 0        0.0 2023-08-10 16:40:50                NaN                     NaN
# 1        0.0 2023-08-10 16:36:14                NaN                     NaN
#
#   appVersion laguage_code country_code  Day  Month  Year rating_type  \
# 0      6.3.2           en           in   10      8  2023    Negative
# 1        NaN           en           in   10      8  2023    Positive
#
#                        normalized_review_description
# ...

# %% [markdown]
# ##### Sentemant analysis

# %%
positive_reviwes_ola["normalized_review_description"].head()
# Out:
# 1         deepak kumar
# 13                nice
# 18     best experience
# 30
# 42    great experience
# Name: normalized_review_description, dtype: object

# %%
from wordcloud import WordCloud
Positive_ola_reviews = ' '.join(positive_reviwes_ola["normalized_review_description"].dropna())


wordcloud = WordCloud(width=800, height=400, background_color='white').generate(Positive_ola_reviews)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  
plt.title('Ola Positive Reviews')
plt.show()

# %%
negative_reviews_ola=ola_df[ola_df["rating_type"]=="Negative"]

# %%
#checking negative words in the reviews of ola 
Negative_ola_reviews = ' '.join(negative_reviews_ola["normalized_review_description"].dropna())


wordcloud = WordCloud(width=800, height=400, background_color='white').generate(Negative_ola_reviews)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  
plt.title('Ola Negative Reviews')
plt.show()

# %%
#checking postive words in the revies of uber 
from wordcloud import WordCloud
Positive_uber_reviews = ' '.join(positive_reviwes_uber["normalized_review_description"].dropna())


wordcloud = WordCloud(width=800, height=400, background_color='white').generate(Positive_uber_reviews)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  
plt.title('Uber Positive Reviews')
plt.show()

# %%
negative_uber_reviews=uber_df[uber_df["rating_type"]=="Negative"]
negative_uber_reviews.head(3)
# Out:
#          source                             review_id       user_name  \
# 0   Google Play  18d6584c-d0e9-4833-a744-f607058aee97       Milky Way
# 5   Google Play  2d096fac-bb98-47d8-989c-0b3a77e56309      Parimala J
# 10  Google Play  9ee056c1-c26b-4e46-82a0-4d3efb35a91c  Annie Bhutiani
#
#    review_title                                 review_description  rating  \
# 0           NaN  Suddenly, the driver can't have my location an...       1
# 5           NaN  App is good but main problem is the drivers ca...       1
# 10          NaN            Very bad experience no customer service       1
#
#     thumbs_up         review_date developer_response developer_response_date  \
# 0         0.0 2023-08-10 17:48:51                NaN                     NaN
# 5         0.0 2023-08-10 17:35:30                NaN                     NaN
# 10        0.0 2023-08-10 17:25:59                NaN                     NaN
#
# ...

# %%
#checking negative words in the revies of uber 
from wordcloud import WordCloud
Negative_uber_reviews = ' '.join(negative_uber_reviews["normalized_review_description"].dropna())


wordcloud = WordCloud(width=800, height=400, background_color='white').generate(Negative_uber_reviews)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  
plt.title('Uber Negative Reviews Uber')
plt.show()

# %% [markdown]
# #### are there days, where bad reviews are written more often like in the weekend or on mondays?

# %%
#ola 
# Extract the name of the day of the week
ola_df['day_of_week'] = ola_df['review_date'].dt.strftime('%A')

# Extract the name of the month
ola_df['month_name'] = ola_df['review_date'].dt.strftime('%B')

# %%
n_ola_df=ola_df[ola_df["rating_type"]=="Negative"]
nn_ola=n_ola_df.groupby("day_of_week")["review_id"].count().sort_values().reset_index()
nn_ola
# Out:
#   day_of_week  review_id
# 0    Thursday      25464
# 1     Tuesday      25834
# 2   Wednesday      25946
# 3      Friday      26731
# 4      Sunday      28132
# 5    Saturday      28312
# 6      Monday      28367

# %%
plt.figure(figsize=(10, 6))
plt.bar(nn_ola['day_of_week'], nn_ola['review_id'])
plt.xlabel('Day of the Week')
plt.ylabel('Rating Count')
plt.title('Rating Count by Day of the Week')
plt.xticks(rotation=45)  
plt.tight_layout()

# %%
#uber 
# Extract the name of the day of the week
uber_df['day_of_week'] = uber_df['review_date'].dt.strftime('%A')

# Extract the name of the month
uber_df['month_name'] = uber_df['review_date'].dt.strftime('%B')

# %%
ola_df["Year"].unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2015, 2016, 2014, 2017, 2012,
#        2013], dtype=int64)

# %%
uber_df["Year"].unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017], dtype=int64)

# %%
ola_df.groupby("Year")["rating_type"].count().reset_index()
# Out:
#     Year  rating_type
# 0   2012            4
# 1   2013            2
# 2   2014           24
# 3   2015          111
# 4   2016           58
# 5   2017           64
# 6   2018        61359
# 7   2019        90475
# 8   2020        55462
# 9   2021        72171
# 10  2022        57820
# 11  2023        20148

# %%
uber_df.groupby("Year")["rating_type"].count().reset_index()
# Out:
#    Year  rating_type
# 0  2017        91730
# 1  2018       178927
# 2  2019       192673
# 3  2020       112512
# 4  2021       158023
# 5  2022       208970
# 6  2023       126781

# %% [markdown]
# the Uber dataset starts from the year 2017 thats why we will do the comparsion of rating from this year

# %%
ola_df_2017=ola_df[ola_df["Year"]>=2017]
ola_df_2017["Year"].unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017], dtype=int64)

# %%
monthly_avg_ratings_ola = ola_df_2017.groupby(ola_df_2017['review_date'].dt.to_period('M'))['rating'].mean()
monthly_avg_ratings_uber = uber_df.groupby(uber_df['review_date'].dt.to_period('M'))['rating'].mean()


plt.figure(figsize=(12, 6))
monthly_avg_ratings_ola.plot(kind='line', marker='o', linestyle='-', color='b', label='Ola Average Monthly Rating')
monthly_avg_ratings_uber.plot(kind='line', marker='o', linestyle='-', color='r', label='Uber Average Monthly Rating')
plt.title('Average Monthly Ratings')
plt.xlabel('Month')
plt.ylabel('Average Rating')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# as we can see here the avarege monthly rating for was stedly and mostly the same until the year 2022 after that the avg rating by uber has increased thats mean that the customer setesfaction of uber customer has increased due to many reasions such (Good App Designe , User Friendly , good Drivers, Good Customer Care...etc)

# %% [markdown]
# ### Uber best year

# %%
# what is the year with the most postive reviews 
p_r_u=positive_reviwes_uber.groupby("Year")["rating"].count().reset_index()
p_r_u
# Out:
#    Year  rating
# 0  2017   62304
# 1  2018  111475
# 2  2019  116453
# 3  2020   73702
# 4  2021   96296
# 5  2022  139664
# 6  2023   94192

# %%
# Create a bar chart from the DataFrame
ax = p_r_u.plot(x='Year', y='rating', kind='bar', figsize=(8, 6), legend=False)

# Customize the chart
plt.title('Positive Revies per Year Uber' )
plt.xlabel('Years')
plt.ylabel('Rating Counts')

# Show the chart
plt.tight_layout()
plt.show()

# %%
ola_df_2017_p=ola_df_2017[ola_df_2017["rating_type"]=="Positive"]
ola_df_2017_n=ola_df_2017[ola_df_2017["rating_type"]=="Negative"]
ola_df_2017_p.head(3)
# Out:
#          source                             review_id       user_name  \
# 1   Google Play  5a0051fb-220a-45b2-ba94-a15a2949218f    Deepak Kumar
# 13  Google Play  36fd0d07-d4c0-49d3-bd86-5ae15aac848d  BICHITRA NAYAK
# 18  Google Play  798f8d1d-cf3f-48f1-a943-93b83e5d7963   kashish yadav
#
#    review_title       review_description  rating  thumbs_up  \
# 1           NaN  Deepak Kumar.... 🙏🙏🙏🙏🙏]       5        0.0
# 13          NaN                     Nice       5        0.0
# 18          NaN          Best experience       5        0.0
#
#            review_date developer_response developer_response_date appVersion  \
# 1  2023-08-10 16:36:14                NaN                     NaN        NaN
# 13 2023-08-10 13:18:46                NaN                     NaN      6.3.1
# 18 2023-08-10 11:57:12                NaN                     NaN      6.3.1
#
#    laguage_code country_code  Day  Month  Year rating_type  \
# 1            en           in   10      8  2023    Positive
# ...

# %%
ola_df_2017_n.head(2)
# Out:
#         source                             review_id         user_name  \
# 0  Google Play  fbc7ffc9-5a89-446e-87fd-d69bf4a7f984     Puipuii Ralte
# 2  Google Play  71ebf933-b734-474d-bb65-a18c90906ed2  Ahamed Azarudeen
#
#   review_title                                 review_description  rating  \
# 0          NaN  The map in Ola is so messed up, i have to pay ...       1
# 2          NaN  Such aa irresponsible app more then I waiting ...       1
#
#    thumbs_up         review_date developer_response developer_response_date  \
# 0        0.0 2023-08-10 16:40:50                NaN                     NaN
# 2        0.0 2023-08-10 16:29:31                NaN                     NaN
#
#   appVersion laguage_code country_code  Day  Month  Year rating_type  \
# 0      6.3.2           en           in   10      8  2023    Negative
# 2      6.3.1           en           in   10      8  2023    Negative
#
#                        normalized_review_description day_of_week month_name
# ...

# %%
p_r_o=ola_df_2017_p.groupby("Year")["rating"].count().reset_index()
p_r_o
# Out:
#    Year  rating
# 0  2017      19
# 1  2018   33229
# 2  2019   45083
# 3  2020   32148
# 4  2021   24951
# 5  2022   13833
# 6  2023    3559

# %%
ax = p_r_o.plot(x='Year', y='rating', kind='bar', figsize=(8, 6), legend=False)
plt.title('Positive Revies per Year Ola')
plt.xlabel('Years')
plt.ylabel('Rating Counts')


plt.tight_layout()
plt.show()

# %%
n_r_o=ola_df_2017_n.groupby("Year")["rating"].count().reset_index()
n_r_o
# Out:
#    Year  rating
# 0  2017      39
# 1  2018   24291
# 2  2019   40492
# 3  2020   20996
# 4  2021   44615
# 5  2022   42196
# 6  2023   16070

# %%
ax = n_r_o.plot(x='Year', y='rating', kind='bar', figsize=(8, 6), legend=False)
plt.title('Negative Revies per Year Ola')
plt.xlabel('Years')
plt.ylabel('Rating Counts')


plt.tight_layout()
plt.show()

# %% [markdown]
# #### App Versions

# %%
ola_df.columns
# Out:
# Index(['source', 'review_id', 'user_name', 'review_title',
#        'review_description', 'rating', 'thumbs_up', 'review_date',
#        'developer_response', 'developer_response_date', 'appVersion',
#        'laguage_code', 'country_code', 'Day', 'Month', 'Year', 'rating_type',
#        'normalized_review_description', 'day_of_week', 'month_name'],
#       dtype='object')

# %%
n_ola_app_v=ola_df["appVersion"].nunique()
print(f"there is {n_ola_app_v} app versions for the ola app")
# Out:
# there is 224 app versions for the ola app

# %% [markdown]
# what are the app versions with the more reviews

# %%
highest_app_version_reviews=ola_df.groupby("appVersion")["user_name"].count().nlargest(5).reset_index()
highest_app_version_reviews
# Out:
#   appVersion  user_name
# 0      5.5.5       7718
# 1      5.5.1       6445
# 2      5.5.2       5306
# 3      5.6.6       5260
# 4      4.7.8       4684

# %%
ax = highest_app_version_reviews.plot(x='appVersion', y='user_name', kind='bar', figsize=(8, 6), legend=False)
plt.title('5 app versions with the heighest review number OLA ')
plt.xlabel('App version')
plt.ylabel('Review Counts')


plt.tight_layout()
plt.show()

# %% [markdown]
# Uber

# %%
n_app_version_uber=uber_df["appVersion"].nunique()
print (f"there is {n_app_version_uber}  Uber app versions ")
# Out:
# there is 603  Uber app versions

# %%
highest_app_version_reviews_uber=uber_df.groupby("appVersion")["user_name"].count().nlargest(5).reset_index()
highest_app_version_reviews_uber
# Out:
#     appVersion  user_name
# 0  4.346.10006      15450
# 1  4.451.10003      15318
# 2  4.422.10002      14401
# 3  4.439.10002      13581
# 4  4.426.10002       9854

# %%
ax = highest_app_version_reviews_uber.plot(x='appVersion', y='user_name', kind='bar', figsize=(8, 6), legend=False)
plt.title('5 app versions with the heighest review number Uber ')
plt.xlabel('App version')
plt.ylabel('Review Counts')


plt.tight_layout()
plt.show()

# %%
n_user_review=negative_reviews_ola[["user_name","normalized_review_description"]]
n_user_review
# Out:
#                user_name                      normalized_review_description
# 0          Puipuii Ralte  map ola messed pay rs extra map incorrect app ...
# 2       Ahamed Azarudeen  aa irresponsible app waiting hour waste app pl...
# 3             Rahil Syed                                              worst
# 4                vin 007  much expensive try uber providing cheap rides ...
# 5        Bhuvanesh Kumar  ola drivers demanding extra money ride auto be...
# ...                  ...                                                ...
# 357693          Jayken17  app useless new users since cant sign referral...
# 357694       cbarath1986  recharge money ola money recharged rs n dint g...
# 357695          MaS Mitt  app hangs signup later get authentication code...
# 357696         vasantha2  one worst app iphonei tried multiple times nev...
# 357697          June Day  company hopeless waited hold forever couple ti...
#
# [188786 rows x 2 columns]

# %% [markdown]
# # 5-Modeling

# %% [markdown]
# ### creating topics from the negative reviews from ola reviews

# %%
from gensim import corpora
from gensim.models import LdaModel
from gensim.parsing.preprocessing import preprocess_string



# Preprocess the text data

documents = n_user_review['normalized_review_description'].dropna().tolist()

# Tokenize and preprocess the text
processed_docs = [preprocess_string(doc) for doc in documents]

# Create a dictionary and a corpus
dictionary = corpora.Dictionary(processed_docs)
corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# Build the LDA model
lda_model = LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15, random_state=42)

# Print the topics and associated words
topics = lda_model.print_topics(num_words=10)
for topic in topics:
    print(topic)
# Out:
# (0, '0.067*"driver" + 0.061*"cancel" + 0.053*"ride" + 0.052*"book" + 0.040*"cab" + 0.039*"time" + 0.032*"ola" + 0.023*"auto" + 0.017*"charg" + 0.017*"locat"')
# (1, '0.043*"app" + 0.042*"ola" + 0.027*"custom" + 0.021*"support" + 0.019*"monei" + 0.018*"account" + 0.017*"work" + 0.014*"issu" + 0.012*"payment" + 0.012*"block"')
# (2, '0.098*"servic" + 0.067*"worst" + 0.053*"ola" + 0.051*"driver" + 0.048*"bad" + 0.042*"app" + 0.032*"custom" + 0.024*"experi" + 0.020*"dont" + 0.018*"good"')
# (3, '0.047*"charg" + 0.033*"ola" + 0.027*"fare" + 0.025*"uber" + 0.020*"app" + 0.017*"price" + 0.016*"rate" + 0.015*"high" + 0.015*"ride" + 0.013*"show"')
# (4, '0.037*"hai" + 0.027*"download" + 0.023*"ola" + 0.020*"app" + 0.014*"aap" + 0.010*"nahi" + 0.010*"nhi" + 0.009*"bakwa" + 0.009*"compani" + 0.009*"chor"')

# %%
topics = lda_model.print_topics(num_words=10)

# Create a bar plot for each topic
for topic_id, topic in topics:
    words = [word.split("*")[1].strip(' "') for word in topic.split(" + ")]
    word_probs = [float(word.split("*")[0]) for word in topic.split(" + ")]
    
    plt.figure(figsize=(8, 6))
    plt.barh(words, word_probs)
    plt.xlabel('Word Probability')
    plt.title(f'Top Words in Topic {topic_id}')
    plt.gca().invert_yaxis()  
    plt.show()

# %% [markdown]
# - Topic 0: "Driver-Related Issues" or "Driver"
# Key Words: "driver," "cancel," "ride," "book," "cab," "time," "ola," "auto," "charg," "locat"
#
# - Topic 1: "App and Customer Support" or "App"
# Key Words: "app," "ola," "custom," "support," "monei," "account," "work," "issu," "payment," "block"
#
# - Topic 2: "Service Quality and Feedback" or "Service Quality"
# Key Words: "servic," "worst," "ola," "driver," "bad," "app," "custom," "experi," "dont," "good"
#
# - Topic 3: "Pricing and Comparisons" or "Pricing"
# Key Words: "charg," "ola," "fare," "uber," "app," "price," "rate," "high," "ride," "show"
#
# - Topic 4: "Non-English Comments" or "Non-English"
# Key Words: "hai," "download," "ola," "app," "aap," "nahi," "nhi," "bakwa," "compani," "chor"

# %%
negative_reviews_ola.columns
# Out:
# Index(['source', 'review_id', 'user_name', 'review_title',
#        'review_description', 'rating', 'thumbs_up', 'review_date',
#        'developer_response', 'developer_response_date', 'appVersion',
#        'laguage_code', 'country_code', 'Day', 'Month', 'Year', 'rating_type',
#        'normalized_review_description'],
#       dtype='object')

# %%
# Create a new column to store assigned topics
negative_reviews_ola['Assigned Topics'] = ''

for index, row in negative_reviews_ola.iterrows():
    review = row['normalized_review_description']
    doc_bow = dictionary.doc2bow(review.split())
    topic_distribution = lda_model[doc_bow]
    
    # Sort topics by probability and select the top one
    top_topic = sorted(topic_distribution, key=lambda x: x[1], reverse=True)[0]
    
    # Assign the topic number to the 'Assigned Topics' column
    negative_reviews_ola.at[index, 'Assigned Topics'] = top_topic[0]
# Out:
# C:\Users\AliMa\AppData\Local\Temp\ipykernel_29944\908983710.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_reviews_ola['Assigned Topics'] = ''

# %%
negative_reviews_ola["Assigned Topics"].unique()
# Out:
# array([3, 4, 2, 1, 0], dtype=object)

# %%
topic_mapping = {
    0: 'Driver-Related Issues',
    1: 'App and Customer Support',
    2: 'Service Quality and Feedback',
    3: 'Pricing and Comparisons',
    4: 'Non-English Comments'
}

# %%
negative_reviews_ola['Topic Category'] = negative_reviews_ola['Assigned Topics'].map(topic_mapping)
# Out:
# C:\Users\AliMa\AppData\Local\Temp\ipykernel_29944\3169112051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_reviews_ola['Topic Category'] = negative_reviews_ola['Assigned Topics'].map(topic_mapping)

# %%
negative_reviews_ola.head(4)
# Out:
#         source                             review_id         user_name  \
# 0  Google Play  fbc7ffc9-5a89-446e-87fd-d69bf4a7f984     Puipuii Ralte
# 2  Google Play  71ebf933-b734-474d-bb65-a18c90906ed2  Ahamed Azarudeen
# 3  Google Play  e1cc0010-60b3-4126-99c2-e8549088566a        Rahil Syed
# 4  Google Play  77cf1be1-b428-4493-ae25-e0f288f79b8f           vin 007
#
#   review_title                                 review_description  rating  \
# 0          NaN  The map in Ola is so messed up, i have to pay ...       1
# 2          NaN  Such aa irresponsible app more then I waiting ...       1
# 3          NaN                                              Worst       1
# 4          NaN  Too much expensive .. try UBer... They are pro...       1
#
#    thumbs_up         review_date developer_response developer_response_date  \
# 0        0.0 2023-08-10 16:40:50                NaN                     NaN
# 2        0.0 2023-08-10 16:29:31                NaN                     NaN
# ...

# %%
topic_counts = negative_reviews_ola['Topic Category'].value_counts()


plt.figure(figsize=(8, 8))  
plt.pie(topic_counts, labels=topic_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  #
plt.title('Topic Category Distribution Ola')


plt.show()

# %% [markdown]
# ## uber topics

# %%
# Preprocess the text data

documents = negative_uber_reviews['normalized_review_description'].dropna().tolist()

# Tokenize and preprocess the text
processed_docs = [preprocess_string(doc) for doc in documents]

# Create a dictionary and a corpus
dictionary = corpora.Dictionary(processed_docs)
corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# Build the LDA model
lda_model = LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15, random_state=42)

# Print the topics and associated words
topics_u = lda_model.print_topics(num_words=10)
for topic in topics_u:
    print(topic)
# Out:
# (0, '0.014*"hai" + 0.013*"que" + 0.013*"uber" + 0.008*"saya" + 0.007*"app" + 0.006*"aap" + 0.005*"bakwa" + 0.005*"hack" + 0.005*"costli" + 0.004*"nahi"')
# (1, '0.076*"driver" + 0.048*"cancel" + 0.043*"ride" + 0.036*"charg" + 0.033*"time" + 0.030*"uber" + 0.026*"book" + 0.024*"trip" + 0.018*"wait" + 0.016*"cab"')
# (2, '0.057*"uber" + 0.015*"driver" + 0.014*"app" + 0.014*"price" + 0.013*"us" + 0.012*"dont" + 0.012*"fare" + 0.011*"like" + 0.011*"car" + 0.009*"better"')
# (3, '0.097*"servic" + 0.082*"custom" + 0.053*"worst" + 0.043*"bad" + 0.037*"app" + 0.032*"support" + 0.027*"uber" + 0.022*"care" + 0.019*"issu" + 0.018*"experi"')
# (4, '0.053*"app" + 0.026*"account" + 0.022*"work" + 0.021*"uber" + 0.018*"card" + 0.017*"payment" + 0.016*"phone" + 0.014*"us" + 0.014*"time" + 0.014*"updat"')

# %%
topics = lda_model.print_topics(num_words=10)


for topic_id, topic in topics_u:
    words = [word.split("*")[1].strip(' "') for word in topic.split(" + ")]
    word_probs = [float(word.split("*")[0]) for word in topic.split(" + ")]
    
    plt.figure(figsize=(8, 6))
    plt.barh(words, word_probs)
    plt.xlabel('Word Probability')
    plt.title(f'Top Words in Topic {topic_id}')
    plt.gca().invert_yaxis()  
    plt.show()

# %%
negative_uber_reviews.head(2)
# Out:
#         source                             review_id   user_name review_title  \
# 0  Google Play  18d6584c-d0e9-4833-a744-f607058aee97   Milky Way          NaN
# 5  Google Play  2d096fac-bb98-47d8-989c-0b3a77e56309  Parimala J          NaN
#
#                                   review_description  rating  thumbs_up  \
# 0  Suddenly, the driver can't have my location an...       1        0.0
# 5  App is good but main problem is the drivers ca...       1        0.0
#
#           review_date developer_response developer_response_date   appVersion  \
# 0 2023-08-10 17:48:51                NaN                     NaN          NaN
# 5 2023-08-10 17:35:30                NaN                     NaN  4.485.10000
#
#   laguage_code country_code  Day  Month  Year rating_type  \
# 0           en           in   10      8  2023    Negative
# 5           en           in   10      8  2023    Negative
#
#                        normalized_review_description
# ...

# %%
negative_uber_reviews['Assigned Topics'] = ''

for index, row in negative_uber_reviews.iterrows():
    review = row['normalized_review_description']
    doc_bow = dictionary.doc2bow(review.split())
    topic_distribution = lda_model[doc_bow]
    
   
    top_topic = sorted(topic_distribution, key=lambda x: x[1], reverse=True)[0]
    
    
    negative_uber_reviews.at[index, 'Assigned Topics'] = top_topic[0]
# Out:
# C:\Users\AliMa\AppData\Local\Temp\ipykernel_29944\4246481360.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_uber_reviews['Assigned Topics'] = ''

# %%
topic_mapping_uber = {
    0: 'Multilingual and Miscellaneous Feedback',
    1: 'Ride Experience and Driver Behavior',
    2: 'Pricing and Ride Quality',
    3: 'Customer Service and Support',
    4: 'App Functionality and Account Issues'
}

# %%
negative_uber_reviews['Topic Category'] = negative_uber_reviews['Assigned Topics'].map(topic_mapping_uber)
# Out:
# C:\Users\AliMa\AppData\Local\Temp\ipykernel_29944\75095705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_uber_reviews['Topic Category'] = negative_uber_reviews['Assigned Topics'].map(topic_mapping_uber)

# %%
negative_uber_reviews.head(4)
# Out:
#          source                             review_id       user_name  \
# 0   Google Play  18d6584c-d0e9-4833-a744-f607058aee97       Milky Way
# 5   Google Play  2d096fac-bb98-47d8-989c-0b3a77e56309      Parimala J
# 10  Google Play  9ee056c1-c26b-4e46-82a0-4d3efb35a91c  Annie Bhutiani
# 15  Google Play  4c9f4c77-2026-488e-925a-0e5ed3a086be        Luckshay
#
#    review_title                                 review_description  rating  \
# 0           NaN  Suddenly, the driver can't have my location an...       1
# 5           NaN  App is good but main problem is the drivers ca...       1
# 10          NaN            Very bad experience no customer service       1
# 15          NaN  Please add dark mode in app as location interf...       1
#
#     thumbs_up         review_date developer_response developer_response_date  \
# 0         0.0 2023-08-10 17:48:51                NaN                     NaN
# 5         0.0 2023-08-10 17:35:30                NaN                     NaN
# ...

# %%
topic_counts = negative_uber_reviews['Topic Category'].value_counts()


plt.figure(figsize=(8, 8))  
plt.pie(topic_counts, labels=topic_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  
plt.title('Topic Category Distribution Uber')


plt.show()
